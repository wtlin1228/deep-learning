# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [04:26, 118KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)

freq = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold / freq[word]) for word in word_counts}

train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    end = idx + R
    target_words = set(words[start: idx] + words[idx+1: end+1])
    return target_words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6134 0.2806 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6350 0.2934 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4699 0.2696 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5770 0.2695 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4845 0.2874 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5607 0.2866 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5590 0.2582 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5290 0.2458 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4794 0.2482 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4319 0.2591 sec/batch
# Nearest to in: ecology, antiprism, gametes, useful, electoral, mozzarella, monica, bucks,
# Nearest to has: whitworth, vinci, bhfuil, lynching, lionhead, archaeopteryx, edict, dodo,
# Nearest to use: dmd, hellene, ocs, violinist, innodb, detritus, topalov, daimon,
# Nearest to often: playhouse, chaldees, created, breviaries, kashrut, creation, hui, totaling,
# Nearest to one: jenner, increasingly, minuit, proclaimed, slippage, hohenstaufen, belfort, nationalised,
# Nearest to for: alcoholic, linking, hypergeometric, blinding, champaign, bizkit, municipal, managed,
# Nearest to have: paged, gross, equipped, inmarsat, hyun, near, undercarriage, treader,
# Nearest to five: reveals, throwing, negev, kia, owned, tagalog, esk, costumed,
# Nearest to smith: reformulated, hco, ordain, reuniting, blah, lepanto, horsepower, hilly,
# Nearest to troops: capelli, judgments, premier, garland, favre, lalor, clearing, starving,
# Nearest to scale: executives, vigil, bre, ellingham, neuroanatomy, gubernatorial, burkinabe, dogmatic,
# Nearest to shows: duplex, rubik, pizza, rsta, ould, intimate, reopen, longbow,
# Nearest to woman: pictures, helsingborg, ostia, music, magician, galindo, unforgettable, griffith,
# Nearest to discovered: gai, clamshell, synchronous, listener, nennius, diffie, rouen, objectives,
# Nearest to older: cl, launched, bedfordshire, books, chief, shortening, loophole, papal,
# Nearest to file: corrupts, makarios, latent, matched, contra, shovel, avedon, coupes,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4881 0.2952 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3886 0.2379 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3412 0.2377 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2253 0.2370 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1947 0.2362 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1325 0.2368 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0775 0.2374 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0720 0.2365 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0028 0.2364 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9787 0.2375 sec/batch
# Nearest to in: useful, ecology, move, fine, port, electoral, gametes, nationalism,
# Nearest to has: whitworth, imposed, already, livingston, edict, blow, bhfuil, vinci,
# Nearest to use: dmd, hellene, violinist, kevin, subexpression, interaction, coast, innodb,
# Nearest to often: created, creation, chaldees, playhouse, nothing, familiar, themes, developing,
# Nearest to one: jenner, undefined, minuit, slippage, proclaimed, increasingly, lai, loose,
# Nearest to for: linking, managed, alcoholic, romantic, municipal, degree, champaign, plot,
# Nearest to have: near, equipped, gross, as, all, bribes, complex, long,
# Nearest to five: throwing, religious, reveals, owned, tagalog, double, negev, obligations,
# Nearest to smith: hco, reformulated, hilly, reuniting, corpses, additional, satire, photos,
# Nearest to troops: access, premier, judgments, above, capelli, garland, and, clearing,
# Nearest to scale: executives, dogmatic, vigil, superimposed, reduction, bre, hugo, total,
# Nearest to shows: duplex, around, pizza, intimate, conspire, rsta, sought, rubik,
# Nearest to woman: pictures, music, ostia, summer, helsingborg, suharto, capita, magician,
# Nearest to discovered: gai, threat, listener, objectives, rouen, punching, theogony, synchronous,
# Nearest to older: cl, launched, books, chief, shortening, papal, develop, announced,
# Nearest to file: corrupts, matched, latent, supplied, makarios, contra, extrapolating, coupes,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9386 0.2413 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8983 0.2353 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8558 0.2357 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8736 0.2389 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8249 0.2367 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8113 0.2375 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7945 0.2370 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7958 0.2371 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7605 0.2403 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7736 0.2369 sec/batch
# Nearest to in: ecology, move, nationalism, useful, port, electoral, monica, edi,
# Nearest to has: whitworth, imposed, vinci, already, blow, edict, enter, persecute,
# Nearest to use: dmd, hellene, violinist, interaction, subexpression, kevin, trips, innodb,
# Nearest to often: created, creation, playhouse, date, chaldees, fail, nothing, familiar,
# Nearest to one: jenner, minuit, slippage, undefined, lai, proclaimed, sergei, sol,
# Nearest to for: linking, alcoholic, romantic, propellers, hendrik, managed, blinding, reformed,
# Nearest to have: equipped, gross, near, fringe, all, bribes, punk, as,
# Nearest to five: six, tagalog, throwing, negev, serve, julian, ric, runways,
# Nearest to smith: reformulated, hilly, reuniting, corpses, hco, sergei, float, allocation,
# Nearest to troops: access, premier, starving, clearing, careers, capelli, garland, judgments,
# Nearest to scale: executives, dogmatic, bre, vigil, reduction, rebuffed, hugo, superimposed,
# Nearest to shows: duplex, rubik, pizza, intimate, rsta, displaced, conspire, around,
# Nearest to woman: pictures, music, summer, ostia, helsingborg, suharto, magician, galindo,
# Nearest to discovered: gai, objectives, threat, listener, conventionally, punching, rouen, preferable,
# Nearest to older: cl, shortening, launched, books, eyewitnesses, assessed, caesarean, chief,
# Nearest to file: latent, corrupts, matched, investigated, supplied, makarios, uncompressed, producer,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7842 0.2405 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7582 0.2354 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7305 0.2375 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7037 0.2357 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7523 0.2398 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6725 0.2388 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7230 0.2378 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7477 0.2382 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6810 0.2371 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6408 0.2374 sec/batch
# Nearest to in: ecology, helix, declension, move, nationalism, monica, privy, edi,
# Nearest to has: whitworth, imposed, lynching, persecute, vinci, edict, southey, already,
# Nearest to use: dmd, subexpression, interaction, hellene, daimon, ocs, innodb, trips,
# Nearest to often: created, fail, chaldees, kashrut, psychiatrists, creation, folds, date,
# Nearest to one: two, jenner, sergei, minuit, lai, seven, slippage, journalist,
# Nearest to for: linking, alcoholic, propellers, smallville, managed, structured, blinding, halakhah,
# Nearest to have: equipped, fringe, gross, as, all, near, complex, diminish,
# Nearest to five: six, tagalog, runways, ric, henri, three, esk, gander,
# Nearest to smith: reformulated, corpses, hco, jim, hilly, reuniting, elsie, sergei,
# Nearest to troops: starving, premier, access, lalor, clearing, judgments, capelli, garland,
# Nearest to scale: executives, dogmatic, bre, reduction, rebuffed, vigil, neuroanatomy, gubernatorial,
# Nearest to shows: duplex, rubik, dumping, rsta, intimate, displaced, conspire, beethoven,
# Nearest to woman: pictures, music, galindo, helsingborg, summer, suharto, ostia, magician,
# Nearest to discovered: gai, listener, objectives, rouen, threat, conventionally, synchronous, experiences,
# Nearest to older: shortening, cl, launched, eyewitnesses, assessed, books, dinh, caesarean,
# Nearest to file: corrupts, latent, uncompressed, makarios, stepmother, inaccuracy, matched, megaliths,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6658 0.2371 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6648 0.2375 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6099 0.2364 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6172 0.2376 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6356 0.2360 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6207 0.2366 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5769 0.1764 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5472 0.2378 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4997 0.2365 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5319 0.2376 sec/batch
# Nearest to in: declension, ecology, showcased, correlated, nationalism, monica, apps, move,
# Nearest to has: whitworth, persecute, vinci, lynching, southey, dodo, presentations, tama,
# Nearest to use: dmd, subexpression, interaction, daimon, ocs, semiconductors, innodb, computation,
# Nearest to often: fail, chaldees, psychiatrists, kashrut, created, dactylic, creation, developing,
# Nearest to one: two, sergei, journalist, seven, jenner, minuit, songwriter, ois,
# Nearest to for: propellers, smallville, structured, alcoholic, linking, halakhah, lobbyist, ambient,
# Nearest to have: as, equipped, fringe, diminish, all, complex, exilic, truncated,
# Nearest to five: six, three, henri, ric, eight, nimzowitsch, runways, gander,
# Nearest to smith: reformulated, elsie, jim, sergei, hco, corpses, reuniting, taj,
# Nearest to troops: starving, lalor, premier, capelli, clearing, garland, careers, profoundly,
# Nearest to scale: executives, reduction, dogmatic, vigil, rebuffed, neuroanatomy, consumption, valence,
# Nearest to shows: duplex, rubik, pizza, rsta, cyberpunk, ould, intimate, halved,
# Nearest to woman: pictures, helsingborg, galindo, music, suharto, minimalism, ostia, summer,
# Nearest to discovered: gai, rouen, listener, diffie, strengthens, threat, synchronous, objectives,
# Nearest to older: shortening, cl, eyewitnesses, launched, assessed, strangle, loophole, dinh,
# Nearest to file: corrupts, latent, uncompressed, megaliths, makarios, inaccuracy, investigated, stepmother,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5062 0.2407 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5163 0.2371 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4697 0.2382 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5482 0.2314 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4850 0.2362 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4652 0.2338 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4672 0.2357 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4026 0.2264 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4277 0.2511 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4399 0.2413 sec/batch
# Nearest to in: correlated, declension, apps, showcased, ecology, move, franchise, nationalism,
# Nearest to has: whitworth, persecute, lynching, presentations, tama, breeding, dodo, bhfuil,
# Nearest to use: dmd, subexpression, interaction, daimon, semiconductors, ocs, detritus, computation,
# Nearest to often: psychiatrists, fail, dactylic, developing, fossilization, created, reacts, folds,
# Nearest to one: two, jenner, sergei, minuit, slippage, unita, mitsui, glandular,
# Nearest to for: propellers, smallville, structured, alcoholic, lubricating, mimic, halakhah, blinding,
# Nearest to have: equipped, diminish, fringe, all, as, complex, sandbox, exilic,
# Nearest to five: six, three, runways, esk, bauhaus, gwh, nimzowitsch, zero,
# Nearest to smith: reformulated, jim, corpses, sergei, reuniting, hco, ordain, elsie,
# Nearest to troops: starving, lalor, premier, clearing, capelli, yugoslav, ergonomics, careers,
# Nearest to scale: executives, reduction, vigil, burkinabe, consumption, neuroanatomy, rebuffed, tolerances,
# Nearest to shows: duplex, rubik, pizza, cyberpunk, intimate, rsta, sponsorships, halved,
# Nearest to woman: pictures, galindo, helsingborg, minimalism, suharto, griffith, unforgettable, ostia,
# Nearest to discovered: aramaean, gai, diffie, tempura, conventionally, rouen, strengthens, listener,
# Nearest to older: shortening, launched, eyewitnesses, dinh, strangle, assessed, loophole, caesarean,
# Nearest to file: corrupts, latent, uncompressed, makarios, megaliths, supplied, investigated, inaccuracy,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4648 0.2436 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3950 0.2432 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4154 0.2963 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3667 0.2590 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4009 0.2568 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4482 0.2589 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3882 0.2577 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3759 0.2575 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4295 0.2575 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3784 0.2583 sec/batch
# Nearest to in: nationalism, helix, correlated, showcased, apps, differs, unhindered, declension,
# Nearest to has: whitworth, persecute, dodo, lynching, presentations, imposed, bhfuil, hobbes,
# Nearest to use: dmd, subexpression, ocs, daimon, semiconductors, interaction, innodb, computation,
# Nearest to often: fail, psychiatrists, created, familiarity, dactylic, fossilization, libertarianism, rorty,
# Nearest to one: two, sergei, jenner, mitsui, six, minuit, unita, glandular,
# Nearest to for: propellers, halakhah, smallville, charon, blinding, structured, unlit, linking,
# Nearest to have: near, fringe, equipped, all, diminish, hyun, rehnquist, adds,
# Nearest to five: six, three, zero, runways, gwh, snowdon, nimzowitsch, bauhaus,
# Nearest to smith: reformulated, jim, hco, sergei, corpses, reuniting, elsie, flynt,
# Nearest to troops: starving, lalor, capelli, premier, yugoslav, promoted, forces, ergonomics,
# Nearest to scale: burkinabe, executives, reduction, vigil, neuroanatomy, tolerances, consumption, superimposed,
# Nearest to shows: duplex, rubik, intimate, pizza, cyberpunk, sponsorships, halved, longbow,
# Nearest to woman: pictures, galindo, helsingborg, minimalism, griffith, suharto, synods, unforgettable,
# Nearest to discovered: aramaean, tempura, gai, diffie, conventionally, natural, counselor, synchronous,
# Nearest to older: shortening, strangle, households, eyewitnesses, dinh, caesarean, assessed, bath,
# Nearest to file: corrupts, latent, uncompressed, supplied, makarios, megaliths, investigated, inaccuracy,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3863 0.2608 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3812 0.2582 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3706 0.2578 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3442 0.2583 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3623 0.2576 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3434 0.2587 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4214 0.2593 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4130 0.2585 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3602 0.2578 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3298 0.2559 sec/batch
# Nearest to in: nationalism, correlated, declension, differs, helix, which, triumph, unhindered,
# Nearest to has: whitworth, presentations, dodo, lynching, hobbes, persecute, most, imposed,
# Nearest to use: dmd, subexpression, ocs, fieldwork, files, developing, semiconductors, oxidative,
# Nearest to often: fail, psychiatrists, familiarity, playhouse, dactylic, rorty, fossilization, created,
# Nearest to one: two, six, sergei, jenner, minuit, proposal, expenditures, glandular,
# Nearest to for: propellers, halakhah, smallville, linking, blinding, structured, sprawling, xyz,
# Nearest to have: rehnquist, all, equipped, fringe, near, adds, treader, diminish,
# Nearest to five: six, three, zero, gwh, four, esk, runways, tagalog,
# Nearest to smith: reformulated, jim, sergei, hco, lepanto, elsie, corpses, satire,
# Nearest to troops: starving, forces, lalor, yugoslav, promoted, guardianship, annexation, attacks,
# Nearest to scale: executives, burkinabe, vigil, reduction, gubernatorial, neuroanatomy, rebuffed, bre,
# Nearest to shows: duplex, rubik, sponsorships, cyberpunk, longbow, md, intimate, pizza,
# Nearest to woman: galindo, pictures, helsingborg, minimalism, synods, griffith, unforgettable, vox,
# Nearest to discovered: natural, conventionally, aramaean, diffie, tempura, gai, experiences, selection,
# Nearest to older: shortening, households, dinh, strangle, eyewitnesses, caesarean, bath, trismegistus,
# Nearest to file: corrupts, latent, uncompressed, investigated, applications, simd, com, supplied,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3633 0.2632 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2923 0.2585 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3855 0.2592 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3929 0.2635 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3927 0.2868 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2790 0.2611 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2925 0.2563 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3480 0.2571 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2075 0.2307 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3314 0.2526 sec/batch
# Nearest to in: helix, nationalism, correlated, triumph, differs, declension, chided, which,
# Nearest to has: whitworth, presentations, dodo, most, hobbes, well, persecute, bhfuil,
# Nearest to use: dmd, ocs, subexpression, files, semiconductors, label, hyphens, developing,
# Nearest to often: familiarity, fail, psychiatrists, dactylic, playhouse, rorty, chaldees, fossilization,
# Nearest to one: two, six, four, zero, seven, five, sergei, eight,
# Nearest to for: propellers, linking, halakhah, blinding, sprawling, structured, unlit, smallville,
# Nearest to have: rehnquist, all, treader, fringe, near, diminish, equipped, ryukyuans,
# Nearest to five: six, three, zero, four, seven, one, two, eight,
# Nearest to smith: hco, reformulated, corpses, elsie, sergei, ewald, jim, moshoeshoe,
# Nearest to troops: forces, starving, yugoslav, lalor, attacks, annexation, promoted, guardianship,
# Nearest to scale: executives, burkinabe, vigil, neuroanatomy, reduction, gubernatorial, section, virginals,
# Nearest to shows: duplex, rubik, sponsorships, cyberpunk, longbow, md, pizza, halved,
# Nearest to woman: galindo, pictures, minimalism, helsingborg, vox, unforgettable, griffith, synods,
# Nearest to discovered: natural, conventionally, aramaean, diffie, tempura, gai, gas, experiences,
# Nearest to older: households, shortening, dinh, strangle, age, eyewitnesses, bath, females,
# Nearest to file: uncompressed, corrupts, latent, makarios, simd, applications, rds, com,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3203 0.2619 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3317 0.2377 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3554 0.1169 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2559 0.2566 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2220 0.2582 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2181 0.2606 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2456 0.2570 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2010 0.2576 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2373 0.2581 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1623 0.2574 sec/batch
# Nearest to in: correlated, triumph, nationalism, declension, differs, chided, franchise, helix,
# Nearest to has: well, whitworth, dodo, most, presentations, bhfuil, hobbes, patches,
# Nearest to use: dmd, subexpression, ocs, semiconductors, daimon, files, hyphens, label,
# Nearest to often: fail, psychiatrists, familiarity, dactylic, playhouse, fossilization, rorty, folds,
# Nearest to one: two, six, zero, four, five, jenner, seven, sergei,
# Nearest to for: propellers, structured, blinding, linking, halakhah, unlit, lubricating, sprawling,
# Nearest to have: all, rehnquist, treader, fringe, near, diminish, adds, clade,
# Nearest to five: six, three, zero, four, two, seven, one, eight,
# Nearest to smith: hco, reformulated, sergei, ewald, elsie, moshoeshoe, reuniting, jim,
# Nearest to troops: forces, starving, attacks, lalor, yugoslav, brigade, promoted, annexation,
# Nearest to scale: executives, burkinabe, neuroanatomy, reduction, vigil, gubernatorial, minarchists, superimposed,
# Nearest to shows: duplex, rubik, sponsorships, halved, longbow, rsta, cyberpunk, intimate,
# Nearest to woman: galindo, minimalism, pictures, helsingborg, vox, synods, unforgettable, griffith,
# Nearest to discovered: natural, tempura, gas, aramaean, conventionally, diffie, gai, rouen,
# Nearest to older: households, shortening, females, size, age, bath, strangle, dinh,
# Nearest to file: uncompressed, corrupts, latent, consortium, wavelet, applications, com, simd,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2721 0.2599 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2204 0.2569 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1957 0.2582 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1208 0.2576 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1713 0.2609 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1813 0.2622 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1693 0.2348 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1951 0.2380 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2107 0.2388 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1731 0.2455 sec/batch
# Nearest to in: declension, correlated, nationalism, cardiovascular, which, differs, helix, triumph,
# Nearest to has: well, most, dodo, whitworth, hobbes, priorities, presentations, persecute,
# Nearest to use: dmd, subexpression, ocs, hyphens, daimon, label, semiconductors, detritus,
# Nearest to often: dactylic, fail, psychiatrists, familiarity, fossilization, playhouse, folds, rorty,
# Nearest to one: two, six, zero, four, five, three, jenner, seven,
# Nearest to for: structured, propellers, halakhah, used, blinding, landsbergis, smallville, using,
# Nearest to have: rehnquist, near, all, adds, fringe, clade, as, treader,
# Nearest to five: six, three, zero, four, two, eight, one, seven,
# Nearest to smith: ewald, sergei, hco, elsie, moshoeshoe, matthieu, reformulated, glastonbury,
# Nearest to troops: forces, starving, brigade, attacks, lalor, yugoslav, promoted, constans,
# Nearest to scale: burkinabe, executives, vigil, neuroanatomy, minarchists, illuminate, spectroscopy, superimposed,
# Nearest to shows: duplex, rubik, sponsorships, lulu, longbow, halved, intimate, cyberpunk,
# Nearest to woman: galindo, minimalism, pictures, vox, helsingborg, griffith, synods, qimei,
# Nearest to discovered: conventionally, tempura, gas, natural, aramaean, diffie, caesium, berzelius,
# Nearest to older: households, shortening, size, females, bath, age, trismegistus, strangle,
# Nearest to file: uncompressed, corrupts, latent, wavelet, consortium, com, makarios, rx,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1474 0.2448 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2284 0.2560 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1649 0.2388 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1365 0.2367 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1723 0.2355 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1636 0.2579 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2147 0.2596 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1574 0.2573 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1595 0.2525 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1558 0.2356 sec/batch
# Nearest to in: correlated, declension, which, differs, helix, cardiovascular, nationalism, buailte,
# Nearest to has: well, most, presentations, patches, priorities, hobbes, sere, lynching,
# Nearest to use: dmd, subexpression, ocs, label, hyphens, daimon, semiconductors, files,
# Nearest to often: dactylic, fail, familiarity, psychiatrists, fossilization, playhouse, rorty, folds,
# Nearest to one: two, six, zero, four, five, three, eight, seven,
# Nearest to for: propellers, blinding, halakhah, structured, used, xyz, waived, linking,
# Nearest to have: rehnquist, adds, all, clade, near, fringe, treader, polycrates,
# Nearest to five: six, three, zero, four, two, one, eight, seven,
# Nearest to smith: sergei, hco, reformulated, ewald, moshoeshoe, elsie, matthieu, jim,
# Nearest to troops: forces, starving, brigade, attacks, lalor, promoted, constans, guardianship,
# Nearest to scale: executives, burkinabe, illuminate, vigil, superimposed, minarchists, gubernatorial, spectroscopy,
# Nearest to shows: duplex, rubik, sponsorships, halved, longbow, lulu, beethoven, cyberpunk,
# Nearest to woman: galindo, minimalism, pictures, vox, helsingborg, unforgettable, qimei, griffith,
# Nearest to discovered: conventionally, natural, gas, tempura, aramaean, caesium, diffie, hellenistic,
# Nearest to older: households, size, shortening, females, age, bath, dinh, trismegistus,
# Nearest to file: uncompressed, consortium, corrupts, com, rds, latent, wavelet, makarios,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2038 0.2370 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1712 0.2372 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1818 0.2491 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1849 0.2594 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1435 0.2621 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1336 0.2596 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1875 0.2535 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1245 0.2362 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2132 0.2113 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2064 0.2248 sec/batch
# Nearest to in: which, triumph, declension, between, vainly, chided, nationalism, helix,
# Nearest to has: well, most, presentations, sere, hobbes, patches, non, lynching,
# Nearest to use: dmd, ocs, subexpression, hyphens, label, daimon, semiconductors, fieldwork,
# Nearest to often: fail, psychiatrists, familiarity, rorty, dactylic, playhouse, folds, fossilization,
# Nearest to one: two, six, four, zero, five, seven, three, eight,
# Nearest to for: halakhah, structured, propellers, waived, weston, blinding, used, ransoming,
# Nearest to have: rehnquist, all, clade, ryukyuans, polycrates, treader, fringe, adds,
# Nearest to five: six, three, zero, four, one, two, eight, seven,
# Nearest to smith: sergei, elsie, matthieu, ewald, moshoeshoe, wilkinson, reformulated, glastonbury,
# Nearest to troops: forces, starving, brigade, lalor, attacks, guardianship, tampere, constans,
# Nearest to scale: executives, burkinabe, illuminate, vigil, gubernatorial, minarchists, ergonomic, virginals,
# Nearest to shows: duplex, rubik, sponsorships, beethoven, halved, rsta, lulu, longbow,
# Nearest to woman: galindo, minimalism, pictures, qimei, lucio, unforgettable, years, vox,
# Nearest to discovered: gas, conventionally, natural, tempura, aramaean, hellenistic, brahe, freiherr,
# Nearest to older: households, shortening, size, females, age, strangle, bath, trismegistus,
# Nearest to file: uncompressed, corrupts, consortium, rds, wavelet, latent, makarios, com,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2170 0.2376 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1036 0.2361 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1251 0.2322 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1633 0.2351 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0546 0.2358 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1503 0.2359 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1460 0.2349 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1159 0.2353 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1788 0.0518 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1127 0.2376 sec/batch
# Nearest to in: which, between, disparities, kwahu, museums, differs, the, monica,
# Nearest to has: well, most, non, sere, presentations, patches, bhfuil, hobbes,
# Nearest to use: dmd, ocs, subexpression, hyphens, daimon, label, semiconductors, term,
# Nearest to often: fail, dactylic, familiarity, playhouse, folds, psychiatrists, fossilization, existance,
# Nearest to one: two, four, zero, six, seven, five, three, eight,
# Nearest to for: structured, using, used, propellers, linking, geometrically, halakhah, blinding,
# Nearest to have: rehnquist, all, ryukyuans, clade, treader, polycrates, basilicas, adds,
# Nearest to five: six, three, zero, four, two, seven, one, eight,
# Nearest to smith: sergei, ewald, elsie, matthieu, moshoeshoe, reformulated, wilkinson, glastonbury,
# Nearest to troops: forces, starving, brigade, attacks, guardianship, lalor, tampere, schengen,
# Nearest to scale: executives, burkinabe, illuminate, ergonomic, vigil, sawmill, section, gubernatorial,
# Nearest to shows: duplex, sponsorships, rubik, halved, lulu, beethoven, amuse, rsta,
# Nearest to woman: galindo, minimalism, lucio, years, qimei, pictures, unforgettable, fertility,
# Nearest to discovered: conventionally, gas, natural, tempura, brahe, aramaean, hellenistic, justus,
# Nearest to older: households, size, shortening, females, age, householder, bath, strangle,
# Nearest to file: uncompressed, corrupts, wavelet, consortium, rds, makarios, browsing, contents,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0789 0.2392 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0716 0.2369 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0631 0.2357 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0239 0.2342 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0755 0.2365 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0331 0.2352 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1180 0.2363 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0870 0.2335 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1100 0.2349 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0253 0.2365 sec/batch
# Nearest to in: the, which, disparities, museums, franchise, from, between, monica,
# Nearest to has: well, most, sere, non, patches, bhfuil, hobbes, gasp,
# Nearest to use: dmd, ocs, subexpression, daimon, hyphens, label, semiconductors, files,
# Nearest to often: fail, familiarity, dactylic, folds, psychiatrists, playhouse, existance, fossilization,
# Nearest to one: two, zero, four, six, five, three, seven, eight,
# Nearest to for: structured, used, using, geometrically, propellers, a, blinding, halakhah,
# Nearest to have: all, rehnquist, clade, ryukyuans, basilicas, treader, near, honeybees,
# Nearest to five: six, three, zero, four, two, one, eight, seven,
# Nearest to smith: reformulated, sergei, moshoeshoe, ordain, glastonbury, matthieu, ewald, wilkinson,
# Nearest to troops: forces, starving, brigade, lalor, guardianship, insurgency, attacks, apc,
# Nearest to scale: burkinabe, executives, illuminate, ergonomic, section, vigil, virginals, demographically,
# Nearest to shows: duplex, sponsorships, rubik, lulu, halved, rsta, beethoven, amuse,
# Nearest to woman: galindo, minimalism, years, lucio, qimei, pictures, fertility, vox,
# Nearest to discovered: conventionally, gas, natural, tempura, hellenistic, aramaean, brahe, justus,
# Nearest to older: households, size, householder, females, age, shortening, bath, family,
# Nearest to file: uncompressed, corrupts, wavelet, consortium, makarios, filesystem, files, rds,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0258 0.2391 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0619 0.2345 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0215 0.2356 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0532 0.2354 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0821 0.2364 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0611 0.2337 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0430 0.2362 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1099 0.2364 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0352 0.2349 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0753 0.2339 sec/batch
# Nearest to in: which, differs, cardiovascular, museums, correlated, the, disparities, etched,
# Nearest to has: well, non, most, sere, patches, priorities, hobbes, trends,
# Nearest to use: dmd, ocs, subexpression, hyphens, daimon, semiconductors, files, label,
# Nearest to often: fail, familiarity, dactylic, folds, existance, psychiatrists, rorty, playhouse,
# Nearest to one: two, zero, four, six, three, five, eight, seven,
# Nearest to for: structured, used, using, geometrically, a, that, halakhah, dunbartonshire,
# Nearest to have: all, rehnquist, clade, ryukyuans, polycrates, honeybees, fringe, adds,
# Nearest to five: six, three, zero, four, two, one, eight, seven,
# Nearest to smith: reformulated, matthieu, hco, moshoeshoe, sergei, ewald, glastonbury, ordain,
# Nearest to troops: forces, starving, brigade, guardianship, insurgency, lalor, constans, schengen,
# Nearest to scale: burkinabe, ergonomic, executives, illuminate, section, demographically, virginals, deduce,
# Nearest to shows: duplex, sponsorships, rubik, lulu, halved, amuse, rsta, beethoven,
# Nearest to woman: galindo, minimalism, qimei, pictures, lucio, wiccans, immaculate, fertility,
# Nearest to discovered: conventionally, gas, brahe, tempura, natural, justus, caesium, evolution,
# Nearest to older: households, householder, size, females, age, shortening, family, couples,
# Nearest to file: uncompressed, wavelet, corrupts, files, filesystem, consortium, makarios, contents,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0682 0.2385 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0799 0.2348 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1072 0.2347 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0484 0.2346 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0545 0.2340 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0390 0.2357 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0699 0.2350 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0528 0.2356 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0986 0.2350 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0507 0.2359 sec/batch
# Nearest to in: the, which, of, by, and, differs, from, museums,
# Nearest to has: well, non, most, patches, sere, priorities, gasp, hobbes,
# Nearest to use: dmd, ocs, subexpression, hyphens, daimon, label, files, semiconductors,
# Nearest to often: folds, fail, familiarity, dactylic, existance, psychiatrists, rorty, playhouse,
# Nearest to one: two, zero, four, six, three, five, eight, seven,
# Nearest to for: structured, used, geometrically, halakhah, using, waived, a, that,
# Nearest to have: all, rehnquist, clade, astrakhan, ryukyuans, polycrates, turf, adds,
# Nearest to five: three, six, zero, four, two, one, eight, seven,
# Nearest to smith: reformulated, ewald, moshoeshoe, wilkinson, hco, glastonbury, sergei, krzyzewski,
# Nearest to troops: forces, starving, brigade, insurgency, guardianship, constans, eritrea, tampere,
# Nearest to scale: burkinabe, executives, ergonomic, section, virginals, illuminate, sawmill, demographically,
# Nearest to shows: duplex, sponsorships, rubik, halved, amuse, lulu, rsta, beethoven,
# Nearest to woman: galindo, minimalism, qimei, pictures, fertility, wiccans, vox, immaculate,
# Nearest to discovered: conventionally, brahe, gas, natural, justus, caesium, evolution, hellenistic,
# Nearest to older: households, householder, females, size, age, shortening, family, trismegistus,
# Nearest to file: uncompressed, filesystem, files, corrupts, consortium, rds, wavelet, contents,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0632 0.2388 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0122 0.2357 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0260 0.2342 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0828 0.2346 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0906 0.2352 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1235 0.2354 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1232 0.2336 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0267 0.2351 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0423 0.2333 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0641 0.2337 sec/batch
# Nearest to in: which, the, differs, declension, and, kwahu, etched, of,
# Nearest to has: well, most, non, sere, patches, gasp, presentations, priorities,
# Nearest to use: dmd, ocs, hyphens, subexpression, semiconductors, files, daimon, label,
# Nearest to often: fail, folds, familiarity, dactylic, playhouse, existance, psychiatrists, rorty,
# Nearest to one: two, zero, four, six, five, three, seven, eight,
# Nearest to for: used, structured, a, tub, that, using, dunbartonshire, halakhah,
# Nearest to have: all, rehnquist, clade, ryukyuans, polycrates, treader, astrakhan, afro,
# Nearest to five: three, six, zero, four, two, one, eight, seven,
# Nearest to smith: reformulated, wilkinson, ewald, hco, moshoeshoe, matthieu, flynt, krzyzewski,
# Nearest to troops: forces, starving, eritrea, brigade, insurgency, guardianship, schengen, tampere,
# Nearest to scale: executives, ergonomic, burkinabe, illuminate, virginals, sawmill, section, indisputably,
# Nearest to shows: sponsorships, duplex, halved, rubik, lulu, beethoven, palatalization, longbow,
# Nearest to woman: galindo, minimalism, pictures, qimei, fertility, lucio, unforgettable, vox,
# Nearest to discovered: conventionally, brahe, natural, tempura, gas, hellenistic, caesium, freiherr,
# Nearest to older: households, size, females, householder, age, shortening, family, bath,
# Nearest to file: uncompressed, filesystem, corrupts, files, contents, wavelet, rds, consortium,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9583 0.2385 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0254 0.2356 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0266 0.2335 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0302 0.2358 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0849 0.2349 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0560 0.2270 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0130 0.2358 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9824 0.2355 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0205 0.2355 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9642 0.2351 sec/batch
# Nearest to in: the, etched, which, kwahu, and, from, differs, of,
# Nearest to has: well, non, sere, most, presentations, trends, patches, gasp,
# Nearest to use: dmd, ocs, hyphens, semiconductors, subexpression, daimon, files, term,
# Nearest to often: fail, familiarity, folds, dactylic, playhouse, psychiatrists, existance, rorty,
# Nearest to one: two, four, zero, six, three, seven, five, eight,
# Nearest to for: used, a, using, structured, weston, and, propellers, tub,
# Nearest to have: all, rehnquist, astrakhan, basilicas, treader, clade, afro, polycrates,
# Nearest to five: three, six, four, zero, two, one, seven, eight,
# Nearest to smith: reformulated, wilkinson, ewald, hco, moshoeshoe, matthieu, sergei, krzyzewski,
# Nearest to troops: starving, forces, brigade, insurgency, constans, guardianship, attacks, ergonomics,
# Nearest to scale: section, executives, sawmill, ergonomic, burkinabe, illuminate, virginals, demographically,
# Nearest to shows: sponsorships, duplex, halved, rubik, waldseem, amuse, rsta, lulu,
# Nearest to woman: galindo, minimalism, qimei, pictures, lucio, nationality, fertility, unforgettable,
# Nearest to discovered: conventionally, brahe, gas, tempura, hellenistic, justus, caesium, libro,
# Nearest to older: households, females, size, householder, age, family, shortening, families,
# Nearest to file: uncompressed, files, filesystem, corrupts, wavelet, contents, rds, consortium,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9864 0.2384 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9278 0.2362 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0495 0.2355 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0238 0.2330 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0227 0.2354 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0076 0.2341 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9111 0.2356 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9623 0.2359 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9227 0.2347 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0134 0.2323 sec/batch
# Nearest to in: the, and, which, kwahu, etched, from, differs, of,
# Nearest to has: well, non, most, sere, trends, patches, livingston, southwest,
# Nearest to use: dmd, hyphens, ocs, semiconductors, daimon, subexpression, label, files,
# Nearest to often: fail, familiarity, playhouse, dactylic, folds, existance, psychiatrists, instep,
# Nearest to one: two, zero, four, three, six, five, seven, nine,
# Nearest to for: used, and, that, a, using, structured, geometrically, tub,
# Nearest to have: all, astrakhan, six, near, turf, adds, fringe, clade,
# Nearest to five: three, six, zero, four, two, one, seven, eight,
# Nearest to smith: reformulated, hco, ewald, wilkinson, moshoeshoe, matthieu, krzyzewski, prioritization,
# Nearest to troops: starving, forces, insurgency, garland, guardianship, ergonomics, constans, brigade,
# Nearest to scale: section, executives, ergonomic, burkinabe, sawmill, illuminate, virginals, demographically,
# Nearest to shows: sponsorships, duplex, rubik, halved, lulu, amuse, waldseem, rsta,
# Nearest to woman: galindo, minimalism, qimei, fertility, lucio, nationality, pictures, women,
# Nearest to discovered: conventionally, brahe, caesium, tempura, gas, hellenistic, berzelius, libro,
# Nearest to older: households, householder, females, size, age, family, shortening, families,
# Nearest to file: uncompressed, files, filesystem, contents, corrupts, wavelet, rds, niklaus,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0036 0.2194 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9796 0.2047 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9798 0.2045 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9913 0.2041 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0300 0.2059 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9570 0.2062 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0020 0.2042 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9715 0.2052 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0142 0.2264 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9771 0.2336 sec/batch
# Nearest to in: the, which, and, by, of, vainly, differs, from,
# Nearest to has: well, non, sere, most, patches, priorities, trends, itv,
# Nearest to use: dmd, hyphens, daimon, ocs, subexpression, semiconductors, label, files,
# Nearest to often: fail, familiarity, folds, playhouse, dactylic, existance, psychiatrists, rorty,
# Nearest to one: two, zero, four, six, nine, eight, three, seven,
# Nearest to for: and, that, used, a, structured, using, geometrically, of,
# Nearest to have: all, astrakhan, turf, rehnquist, fringe, basilicas, clade, near,
# Nearest to five: three, zero, six, four, two, eight, one, seven,
# Nearest to smith: reformulated, hco, wilkinson, ewald, krzyzewski, moshoeshoe, prioritization, matthieu,
# Nearest to troops: starving, forces, insurgency, guardianship, constans, garland, tampere, schengen,
# Nearest to scale: section, ergonomic, executives, demographically, sawmill, illuminate, virginals, richter,
# Nearest to shows: sponsorships, duplex, rubik, amuse, lulu, halved, laurentiis, asimov,
# Nearest to woman: galindo, minimalism, qimei, nationality, fertility, pictures, lucio, immaculate,
# Nearest to discovered: conventionally, brahe, caesium, evolution, libro, justus, berzelius, gas,
# Nearest to older: households, females, householder, size, age, family, families, income,
# Nearest to file: uncompressed, files, filesystem, contents, corrupts, consortium, wavelet, makarios,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0166 0.2394 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9843 0.2365 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9540 0.2344 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0007 0.2360 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0333 0.2354 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0112 0.2350 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9911 0.2340 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9881 0.2362 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9716 0.2343 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0360 0.2379 sec/batch
# Nearest to in: the, which, and, of, by, from, to, kwahu,
# Nearest to has: well, non, most, sere, patches, trends, hobbes, is,
# Nearest to use: dmd, hyphens, ocs, daimon, subexpression, semiconductors, uses, label,
# Nearest to often: fail, familiarity, folds, existance, psychiatrists, dactylic, playhouse, kashrut,
# Nearest to one: two, four, zero, six, three, nine, seven, eight,
# Nearest to for: and, used, a, that, geometrically, halakhah, using, structured,
# Nearest to have: all, astrakhan, rehnquist, turf, these, six, ryukyuans, clade,
# Nearest to five: three, six, zero, four, two, eight, one, seven,
# Nearest to smith: reformulated, hco, wilkinson, ewald, krzyzewski, moshoeshoe, prioritization, matthieu,
# Nearest to troops: starving, forces, guardianship, tampere, insurgency, constans, garland, brigade,
# Nearest to scale: executives, section, richter, sawmill, demographically, ergonomic, samar, virginals,
# Nearest to shows: sponsorships, duplex, rubik, halved, lulu, amuse, laurentiis, ratings,
# Nearest to woman: galindo, fertility, nationality, minimalism, qimei, pictures, immaculate, women,
# Nearest to discovered: conventionally, brahe, caesium, justus, hellenistic, gas, berzelius, libro,
# Nearest to older: households, females, age, householder, size, families, family, income,
# Nearest to file: uncompressed, contents, filesystem, files, corrupts, consortium, makarios, rds,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9384 0.2391 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0579 0.2349 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0156 0.2345 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0296 0.2334 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9479 0.2353 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9714 0.2336 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9883 0.2352 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9416 0.2338 sec/batch
# ...
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7467 0.2370 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8396 0.2400 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7834 0.2375 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8412 0.2347 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8774 0.2363 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8420 0.2353 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8475 0.2376 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8551 0.2346 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8921 0.2056 sec/batch
# Nearest to in: the, and, of, as, a, to, also, for,
# Nearest to has: in, is, been, well, a, s, non, of,
# Nearest to use: uses, hyphens, users, ocs, dmd, permitted, used, infringed,
# Nearest to often: such, as, used, playhouse, of, psychiatrists, fail, particularly,
# Nearest to one: two, four, three, zero, nine, eight, six, five,
# Nearest to for: and, the, in, used, a, to, of, as,
# Nearest to have: are, these, several, not, to, who, some, all,
# Nearest to five: three, zero, four, six, one, two, eight, seven,
# Nearest to smith: wilkinson, early, ewald, reformulated, s, levine, interleaving, walter,
# Nearest to troops: garland, forces, igf, starving, eritrea, tampere, brigade, chancellorsville,
# Nearest to scale: richter, scales, subdominant, section, meantone, samar, electrotechnical, sawmill,
# Nearest to shows: show, sponsorships, laurentiis, cbs, wonka, ratings, nbc, display,
# Nearest to woman: women, galindo, fertility, immaculate, relationship, qimei, minimalism, nationality,
# Nearest to discovered: found, discovery, conventionally, mehr, giants, approached, ashoka, survived,
# Nearest to older: households, females, age, householder, families, size, average, versus,
# Nearest to file: uncompressed, files, contents, mug, bock, makarios, mondeo, stepmother,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8157 0.2405 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8353 0.2344 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8213 0.2345 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8818 0.2360 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8746 0.2345 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8985 0.2366 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8622 0.2349 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8636 0.2363 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8542 0.2352 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8820 0.2360 sec/batch
# Nearest to in: the, of, and, as, to, a, from, which,
# Nearest to has: is, been, well, in, it, a, non, the,
# Nearest to use: uses, hyphens, users, permitted, ocs, dmd, oxides, term,
# Nearest to often: as, such, used, of, particularly, hiberno, fail, psychiatrists,
# Nearest to one: two, four, three, zero, eight, nine, seven, six,
# Nearest to for: and, the, a, in, used, to, other, as,
# Nearest to have: are, several, these, all, than, some, not, who,
# Nearest to five: three, zero, four, six, one, two, eight, seven,
# Nearest to smith: wilkinson, early, ewald, reformulated, levine, interleaving, adv, walter,
# Nearest to troops: garland, forces, igf, eritrea, tampere, starving, brigade, allies,
# Nearest to scale: richter, scales, section, meantone, electrotechnical, subdominant, sawmill, samar,
# Nearest to shows: show, cbs, sponsorships, ratings, laurentiis, nbc, tours, lulu,
# Nearest to woman: galindo, women, fertility, minimalism, nationality, immaculate, qimei, sexist,
# Nearest to discovered: discovery, found, giants, conventionally, mehr, brahe, survived, discoveries,
# Nearest to older: households, females, age, families, householder, size, versus, average,
# Nearest to file: uncompressed, files, contents, bock, mug, mondeo, makarios, stepmother,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8403 0.2390 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8248 0.2352 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8353 0.2351 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8382 0.2338 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8900 0.2394 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8106 0.2381 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9925 0.2356 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8929 0.2346 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9247 0.2350 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8006 0.2355 sec/batch
# Nearest to in: the, of, and, as, to, from, a, which,
# Nearest to has: is, been, in, well, it, the, and, of,
# Nearest to use: uses, hyphens, permitted, users, ocs, dmd, oxides, infringed,
# Nearest to often: used, as, such, of, particularly, sometimes, fail, psychiatrists,
# Nearest to one: two, four, zero, three, nine, five, eight, seven,
# Nearest to for: and, the, a, in, to, used, other, as,
# Nearest to have: are, these, several, who, not, some, than, to,
# Nearest to five: three, zero, four, one, six, two, eight, seven,
# Nearest to smith: wilkinson, early, ewald, reformulated, interleaving, levine, walter, adv,
# Nearest to troops: forces, garland, igf, brigade, eritrea, tampere, allies, diplomatique,
# Nearest to scale: richter, scales, subdominant, section, meantone, electrotechnical, sawmill, samar,
# Nearest to shows: show, sponsorships, ratings, laurentiis, tours, nbc, cbs, bitola,
# Nearest to woman: galindo, women, minimalism, fertility, nationality, qimei, relationship, female,
# Nearest to discovered: discovery, found, conventionally, mehr, giants, approached, survived, ashoka,
# Nearest to older: households, females, age, families, householder, size, average, versus,
# Nearest to file: uncompressed, contents, files, bock, mug, makarios, mondeo, stepmother,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7999 0.2363 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8475 0.2344 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7924 0.2367 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8815 0.2357 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8437 0.2356 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8771 0.2343 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8686 0.1545 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8737 0.2358 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8226 0.2358 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8503 0.2367 sec/batch
# Nearest to in: the, of, and, as, a, from, to, which,
# Nearest to has: is, well, in, been, non, also, a, it,
# Nearest to use: uses, hyphens, permitted, users, used, oxides, ocs, term,
# Nearest to often: as, used, particularly, such, playhouse, hiberno, fail, psychiatrists,
# Nearest to one: two, four, three, zero, eight, nine, five, six,
# Nearest to for: and, the, a, other, in, to, as, used,
# Nearest to have: are, these, who, several, not, astrakhan, some, all,
# Nearest to five: three, four, zero, one, six, two, eight, seven,
# Nearest to smith: wilkinson, early, ewald, reformulated, interleaving, moulded, levine, adv,
# Nearest to troops: garland, forces, igf, eritrea, tampere, chancellorsville, pascua, constans,
# Nearest to scale: richter, scales, subdominant, section, meantone, electrotechnical, sawmill, dates,
# Nearest to shows: show, ratings, laurentiis, cbs, sponsorships, tours, berkelium, nbc,
# Nearest to woman: galindo, women, qimei, minimalism, fertility, nationality, relationship, immaculate,
# Nearest to discovered: discovery, found, survived, approached, conventionally, ashoka, ventris, mehr,
# Nearest to older: households, females, families, age, householder, size, versus, average,
# Nearest to file: uncompressed, files, contents, bock, mug, mondeo, makarios, corrupts,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8204 0.2376 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8320 0.2363 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8139 0.2357 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8778 0.2342 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8295 0.2341 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8301 0.2352 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8650 0.2351 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7033 0.2355 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8223 0.2356 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8021 0.2351 sec/batch
# Nearest to in: the, and, of, as, a, to, which, from,
# Nearest to has: in, is, been, a, the, well, it, of,
# Nearest to use: uses, hyphens, used, permitted, users, ocs, for, oxides,
# Nearest to often: used, as, such, of, particularly, fail, tattoos, psychiatrists,
# Nearest to one: four, two, three, zero, eight, five, six, seven,
# Nearest to for: and, the, a, other, to, in, of, used,
# Nearest to have: are, these, several, some, all, to, not, who,
# Nearest to five: three, zero, four, one, six, two, eight, seven,
# Nearest to smith: wilkinson, early, ewald, levine, reformulated, adv, moulded, walter,
# Nearest to troops: forces, garland, igf, chancellorsville, brigade, starving, ambushes, lalor,
# Nearest to scale: richter, scales, subdominant, meantone, section, payout, electrotechnical, sawmill,
# Nearest to shows: show, laurentiis, cbs, ratings, sponsorships, berkelium, tours, nbc,
# Nearest to woman: women, galindo, fertility, minimalism, nationality, immaculate, female, qimei,
# Nearest to discovered: discovery, found, ashoka, conventionally, were, ventris, survived, approached,
# Nearest to older: households, females, families, householder, age, size, versus, average,
# Nearest to file: uncompressed, files, bock, contents, mug, makarios, mondeo, stepmother,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7926 0.2371 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8264 0.2352 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8903 0.2336 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8079 0.2399 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8361 0.2364 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9097 0.2354 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8024 0.2364 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8230 0.2347 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8333 0.2336 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8331 0.2338 sec/batch
# Nearest to in: the, and, of, as, a, to, which, from,
# Nearest to has: in, the, is, been, well, a, it, also,
# Nearest to use: uses, hyphens, users, permitted, used, daimon, dmd, ocs,
# Nearest to often: as, of, used, such, tattoos, particularly, fail, or,
# Nearest to one: four, two, three, zero, eight, nine, six, five,
# Nearest to for: and, the, other, a, in, of, as, to,
# Nearest to have: are, these, several, as, some, not, all, to,
# Nearest to five: three, four, zero, one, six, two, eight, seven,
# Nearest to smith: wilkinson, early, ewald, levine, s, walter, moulded, reformulated,
# Nearest to troops: garland, forces, igf, constans, chancellorsville, ergonomics, hangzhou, pascua,
# Nearest to scale: richter, scales, subdominant, meantone, sawmill, ergonomic, electrotechnical, payout,
# Nearest to shows: show, laurentiis, nbc, ratings, sponsorships, tours, cbs, mirrors,
# Nearest to woman: women, galindo, fertility, qimei, minimalism, immaculate, nationality, female,
# Nearest to discovered: discovery, found, survived, were, approached, brahe, ashoka, giants,
# Nearest to older: females, households, families, versus, age, householder, size, family,
# Nearest to file: uncompressed, files, bock, contents, mug, makarios, mondeo, stepmother,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8619 0.2370 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8653 0.2350 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8408 0.2344 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8373 0.2353 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8540 0.2359 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8187 0.2351 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8294 0.2364 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8567 0.2354 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8227 0.2362 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8456 0.2341 sec/batch
# Nearest to in: the, of, and, to, a, as, which, from,
# Nearest to has: is, in, it, been, well, the, a, of,
# Nearest to use: uses, users, hyphens, permitted, used, ocs, for, daimon,
# Nearest to often: as, used, of, such, or, sometimes, the, particularly,
# Nearest to one: two, four, three, zero, eight, nine, six, five,
# Nearest to for: and, the, a, to, of, in, other, as,
# Nearest to have: are, these, some, several, to, not, been, all,
# Nearest to five: three, zero, four, six, one, two, eight, seven,
# Nearest to smith: wilkinson, early, ewald, levine, reformulated, moulded, walter, interleaving,
# Nearest to troops: forces, garland, igf, allies, constans, chancellorsville, hangzhou, tampere,
# Nearest to scale: richter, scales, subdominant, sawmill, payout, electrotechnical, pontificia, meantone,
# Nearest to shows: ratings, show, laurentiis, sponsorships, cbs, nbc, tours, berkelium,
# Nearest to woman: women, fertility, galindo, female, minimalism, immaculate, qimei, nationality,
# Nearest to discovered: discovery, found, survived, conventionally, ashoka, giants, ventris, brahe,
# Nearest to older: households, females, versus, families, age, householder, size, below,
# Nearest to file: uncompressed, files, contents, bock, mug, infrequently, kallisti, makarios,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8555 0.2382 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8187 0.2373 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9371 0.2373 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8816 0.2339 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8927 0.2349 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8201 0.2399 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7904 0.2345 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8263 0.2754 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7534 0.2763 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8667 0.2577 sec/batch
# Nearest to in: the, and, of, a, to, as, from, is,
# Nearest to has: is, in, a, well, been, the, it, and,
# Nearest to use: uses, hyphens, used, users, permitted, ocs, above, for,
# Nearest to often: as, such, of, used, for, particularly, the, with,
# Nearest to one: four, two, nine, three, zero, eight, five, seven,
# Nearest to for: and, the, a, other, in, to, as, of,
# Nearest to have: are, these, several, some, astrakhan, to, been, not,
# Nearest to five: three, zero, four, one, six, two, eight, seven,
# Nearest to smith: wilkinson, early, ewald, reformulated, levine, tradition, moulded, wetton,
# Nearest to troops: forces, garland, igf, brigade, chancellorsville, hangzhou, tampere, allies,
# Nearest to scale: richter, scales, subdominant, sawmill, meantone, electrotechnical, payout, ergonomic,
# Nearest to shows: show, laurentiis, nbc, ratings, tours, cbs, sponsorships, berkelium,
# Nearest to woman: women, fertility, galindo, minimalism, female, qimei, immaculate, nationality,
# Nearest to discovered: discovery, found, survived, approached, ashoka, conventionally, ventris, mehr,
# Nearest to older: females, households, versus, families, age, householder, size, family,
# Nearest to file: uncompressed, files, contents, bock, mug, kallisti, uncredited, infrequently,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8373 0.2465 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8011 0.2519 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
